# %% [markdown]
# <a href="https://colab.research.google.com/github/smze/T3-1/blob/main/Phase03_Part01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1
# ## Subpart 1: Multimodal texts & images

# %%
# download image datasets
# !pip install --upgrade --no-cache-dir gdown

# !gdown "1GAZgPpTUBSfhne-Tp0GDkvSHuq6EMMbj&export=download"
# !unzip "/content/train_ende.zip"

# !gdown "1B9ZFmSTqfTMaqJ15nQDrRNLqBvo-B39W&export=download"
# !unzip "/content/test.zip"

# !gdown "12HM8uVNjFg-HRZ15ADue4oLGFAYQwvTA&export=download"
# !unzip "/content/dev.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dev/1054.jpg
#   inflating: dev/1055.jpg
#   inflating: dev/1056.jpg
#   inflating: dev/1057.jpg
#   inflating: dev/1058.jpg
#   inflating: dev/1059.jpg
#   inflating: dev/106.jpg
#   inflating: dev/1060.jpg
#   inflating: dev/1061.jpg
#   inflating: dev/1062.jpg
#   inflating: dev/1063.jpg
#   inflating: dev/1064.jpg
#   inflating: dev/1065.jpg
#   inflating: dev/1066.jpg
#   inflating: dev/1067.jpg
#   inflating: dev/1068.jpg
#   inflating: dev/1069.jpg
#   inflating: dev/107.jpg
#   inflating: dev/1070.jpg
#   inflating: dev/1071.jpg
#   inflating: dev/1072.jpg
#   inflating: dev/1073.jpg
#   inflating: dev/1074.jpg
#   inflating: dev/1075.jpg
#   inflating: dev/1076.jpg
#   inflating: dev/1077.jpg
#   inflating: dev/1078.jpg
#   inflating: dev/1079.jpg
#   inflating: dev/108.jpg
#   inflating: dev/1080.jpg
#   inflating: dev/1081.jpg
#   inflating: dev/1082.jpg
#   inflating: dev/1083.jpg
#   inflating: dev/1084.jpg
#   inflating: dev/1085.jpg
#   inflating: dev/1086.jpg
#   inflating: dev/1087.jpg
#   inflating: dev/1088.jpg
#   inflating: dev/1089.jpg
#   inflating: dev/109.jpg
#   inflating: dev/1090.jpg
#   inflating: dev/1091.jpg
#   inflating: dev/1092.jpg
#   inflating: dev/1093.jpg
#   inflating: dev/1094.jpg
#   inflating: dev/1095.jpg
#   inflating: dev/1096.jpg
#   inflating: dev/1097.jpg
#   inflating: dev/1098.jpg
#   inflating: dev/1099.jpg
#   inflating: dev/11.jpg
#   inflating: dev/110.jpg
#   inflating: dev/1100.jpg
#   inflating: dev/1101.jpg
#   inflating: dev/1102.jpg
#   inflating: dev/1103.jpg
#   inflating: dev/1104.jpg
#   inflating: dev/1105.jpg
#   inflating: dev/1106.jpg
#   inflating: dev/1107.jpg
#   inflating: dev/1108.jpg
#   inflating: dev/1109.jpg
#   inflating: dev/111.jpg
#   inflating: dev/1110.jpg
#   inflating: dev/1111.jpg
#   inflating: dev/1112.jpg
#   inflating: dev/1113.jpg
#   inflating: dev/1114.jpg
#   inflating: dev/1115.jpg
#   inflating: dev/1116.jpg
#   inflating: dev/1117.jpg
#   inflating: dev/1118.jpg
#   inflating: dev/1119.jpg
#   inflating: dev/112.jpg
#   inflating: dev/1120.jpg
#   inflating: dev/1121.jpg
#   inflating: dev/1122.jpg
#   inflating: dev/1123.jpg
#   inflating: dev/1124.jpg
#   inflating: dev/1125.jpg
#   inflating: dev/1126.jpg
#   inflating: dev/1127.jpg
#   inflating: dev/1128.jpg
#   inflating: dev/1129.jpg
#   inflating: dev/113.jpg
#   inflating: dev/1130.jpg
#   inflating: dev/1131.jpg
#   inflating: dev/1132.jpg
#   inflating: dev/1133.jpg
#   inflating: dev/1134.jpg
#   inflating: dev/1135.jpg
#   inflating: dev/1136.jpg
#   inflating: dev/1137.jpg
#   inflating: dev/1138.jpg
#   inflating: dev/1139.jpg
#   inflating: dev/114.jpg
#   inflating: dev/1140.jpg
#   inflating: dev/1141.jpg
#   inflating: dev/1142.jpg
#   inflating: dev/1143.jpg
#   inflating: dev/1144.jpg
#   inflating: dev/1145.jpg
#   inflating: dev/1146.jpg
#   inflating: dev/1147.jpg
#   inflating: dev/1148.jpg
#   inflating: dev/1149.jpg
#   inflating: dev/115.jpg
#   inflating: dev/1150.jpg
#   inflating: dev/1151.jpg
#   inflating: dev/1152.jpg
#   inflating: dev/1153.jpg
#   inflating: dev/1154.jpg
#   inflating: dev/1155.jpg
#   inflating: dev/1156.jpg
#   inflating: dev/1157.jpg
#   inflating: dev/1158.jpg
#   inflating: dev/1159.jpg
#   inflating: dev/116.jpg
#   inflating: dev/1160.jpg
#   inflating: dev/1161.jpg
#   inflating: dev/1162.jpg
#   inflating: dev/1163.jpg
#   inflating: dev/1164.jpg
#   inflating: dev/1165.jpg
#   inflating: dev/1166.jpg
#   inflating: dev/1167.jpg
#   inflating: dev/1168.jpg
#   inflating: dev/1169.jpg
#   inflating: dev/117.jpg
#   inflating: dev/1170.jpg
#   inflating: dev/1171.jpg
#   inflating: dev/1172.jpg
#   inflating: dev/1173.jpg
#   inflating: dev/1174.jpg
#   inflating: dev/1175.jpg
#   inflating: dev/1176.jpg
#   inflating: dev/1177.jpg
#   inflating: dev/1178.jpg
#   inflating: dev/1179.jpg
#   inflating: dev/118.jpg
#   inflating: dev/1180.jpg
#   inflating: dev/1181.jpg
#   inflating: dev/1182.jpg
#   inflating: dev/1183.jpg
#   inflating: dev/1184.jpg
#   inflating: dev/1185.jpg
#   inflating: dev/1186.jpg
#   inflating: dev/1187.jpg
#   inflating: dev/1188.jpg
#   inflating: dev/1189.jpg
#   inflating: dev/119.jpg
#   inflating: dev/1190.jpg
#   inflating: dev/1191.jpg
#   inflating: dev/1192.jpg
#   inflating: dev/1193.jpg
#   inflating: dev/1194.jpg
#   inflating: dev/1195.jpg
#   inflating: dev/1196.jpg
#   inflating: dev/1197.jpg
#   inflating: dev/1198.jpg
#   inflating: dev/1199.jpg
#   inflating: dev/12.jpg
#   inflating: dev/120.jpg
#   inflating: dev/1200.jpg
#   inflating: dev/1201.jpg
#   inflating: dev/1202.jpg
#   inflating: dev/1203.jpg
#   inflating: dev/1204.jpg
#   inflating: dev/1205.jpg
#   inflating: dev/1206.jpg
#   inflating: dev/1207.jpg
#   inflating: dev/1208.jpg
#   inflating: dev/1209.jpg
#   inflating: dev/121.jpg
#   inflating: dev/1210.jpg
#   inflating: dev/1211.jpg
#   inflating: dev/1212.jpg
#   inflating: dev/1213.jpg
#   inflating: dev/1214.jpg
#   inflating: dev/1215.jpg
#   inflating: dev/1216.jpg
#   inflating: dev/1217.jpg
#   inflating: dev/1218.jpg
#   inflating: dev/1219.jpg
#   inflating: dev/122.jpg
#   inflating: dev/1220.jpg
#   inflating: dev/1221.jpg
#   inflating: dev/1222.jpg
#   inflating: dev/1223.jpg
#   inflating: dev/1224.jpg
#   inflating: dev/1225.jpg
#   inflating: dev/1226.jpg
#   inflating: dev/1227.jpg
#   inflating: dev/1228.jpg
#   inflating: dev/1229.jpg
#   inflating: dev/123.jpg
#   inflating: dev/1230.jpg
#   inflating: dev/1231.jpg
#   inflating: dev/1232.jpg
#   inflating: dev/1233.jpg
#   inflating: dev/1234.jpg
#   inflating: dev/1235.jpg
#   inflating: dev/1236.jpg
#   inflating: dev/1237.jpg
#   inflating: dev/1238.jpg
#   inflating: dev/1239.jpg
#   inflating: dev/124.jpg
#   inflating: dev/1240.jpg
#   inflating: dev/1241.jpg
#   inflating: dev/1242.jpg
#   inflating: dev/1243.jpg
#   inflating: dev/1244.jpg
#   inflating: dev/1245.jpg
#   inflating: dev/1246.jpg
#   inflating: dev/1247.jpg
#   inflating: dev/1248.jpg
#   inflating: dev/1249.jpg
#   inflating: dev/125.jpg
#   inflating: dev/1250.jpg
#   inflating: dev/1251.jpg
#   inflating: dev/1252.jpg
#   inflating: dev/1253.jpg
#   inflating: dev/1254.jpg
#   inflating: dev/1255.jpg
#   inflating: dev/1256.jpg
#   inflating: dev/1257.jpg
#   inflating: dev/1258.jpg
#   inflating: dev/1259.jpg
#   inflating: dev/126.jpg
#   inflating: dev/1260.jpg
#   inflating: dev/1261.jpg
#   inflating: dev/1262.jpg
#   inflating: dev/1263.jpg
#   inflating: dev/1264.jpg
#   inflating: dev/1265.jpg
#   inflating: dev/1266.jpg
#   inflating: dev/1267.jpg
#   inflating: dev/1268.jpg
#   inflating: dev/1269.jpg
#   inflating: dev/127.jpg
#   inflating: dev/1270.jpg
#   inflating: dev/1271.jpg
#   inflating: dev/1272.jpg
#   inflating: dev/1273.jpg
#   inflating: dev/1274.jpg
#   inflating: dev/1275.jpg
#   inflating: dev/1276.jpg
#   inflating: dev/1277.jpg
#   inflating: dev/1278.jpg
#   inflating: dev/1279.jpg
#   inflating: dev/128.jpg
#   inflating: dev/1280.jpg
#   inflating: dev/1281.jpg
#   inflating: dev/1282.jpg
#   inflating: dev/1283.jpg
#   inflating: dev/1284.jpg
#   inflating: dev/1285.jpg
#   inflating: dev/1286.jpg
#   inflating: dev/1287.jpg
#   inflating: dev/1288.jpg
#   inflating: dev/1289.jpg
#   inflating: dev/129.jpg
#   inflating: dev/1290.jpg
#   inflating: dev/1291.jpg
#   inflating: dev/1292.jpg
#   inflating: dev/1293.jpg
#   inflating: dev/1294.jpg
#   inflating: dev/1295.jpg
#   inflating: dev/1296.jpg
#   inflating: dev/1297.jpg
#   inflating: dev/1298.jpg
#   inflating: dev/1299.jpg
#   inflating: dev/13.jpg
#   inflating: dev/130.jpg
#   inflating: dev/1300.jpg
#   inflating: dev/1301.jpg
#   inflating: dev/1302.jpg
#   inflating: dev/1303.jpg
#   inflating: dev/1304.jpg
#   inflating: dev/1305.jpg
#   inflating: dev/1306.jpg
#   inflating: dev/1307.jpg
#   inflating: dev/1308.jpg
#   inflating: dev/1309.jpg
#   inflating: dev/131.jpg
#   inflating: dev/1310.jpg
#   inflating: dev/1311.jpg
#   inflating: dev/1312.jpg
#   inflating: dev/1313.jpg
#   inflating: dev/1314.jpg
#   inflating: dev/1315.jpg
#   inflating: dev/1316.jpg
#   inflating: dev/1317.jpg
#   inflating: dev/1318.jpg
#   inflating: dev/1319.jpg
#   inflating: dev/132.jpg
#   inflating: dev/1320.jpg
#   inflating: dev/1321.jpg
#   inflating: dev/1322.jpg
#   inflating: dev/1323.jpg
#   inflating: dev/1324.jpg
#   inflating: dev/1325.jpg
#   inflating: dev/1326.jpg
#   inflating: dev/1327.jpg
#   inflating: dev/1328.jpg
#   inflating: dev/1329.jpg
#   inflating: dev/133.jpg
#   inflating: dev/1330.jpg
#   inflating: dev/1331.jpg
#   inflating: dev/1332.jpg
#   inflating: dev/1333.jpg
#   inflating: dev/1334.jpg
#   inflating: dev/1335.jpg
#   inflating: dev/1336.jpg
#   inflating: dev/1337.jpg
#   inflating: dev/1338.jpg
#   inflating: dev/1339.jpg
#   inflating: dev/134.jpg
#   inflating: dev/1340.jpg
#   inflating: dev/1341.jpg
#   inflating: dev/1342.jpg
#   inflating: dev/1343.jpg
#   inflating: dev/1344.jpg
#   inflating: dev/1345.jpg
#   inflating: dev/1346.jpg
#   inflating: dev/1347.jpg
#   inflating: dev/1348.jpg
#   inflating: dev/1349.jpg
#   inflating: dev/135.jpg
#   inflating: dev/1350.jpg
#   inflating: dev/1351.jpg
#   inflating: dev/1352.jpg
#   inflating: dev/1353.jpg
#   inflating: dev/1354.jpg
#   inflating: dev/1355.jpg
#   inflating: dev/1356.jpg
#   inflating: dev/1357.jpg
#   inflating: dev/1358.jpg
#   inflating: dev/1359.jpg
#   inflating: dev/136.jpg
#   inflating: dev/1360.jpg
#   inflating: dev/1361.jpg
#   inflating: dev/1362.jpg
#   inflating: dev/1363.jpg
#   inflating: dev/1364.jpg
#   inflating: dev/1365.jpg
#   inflating: dev/1366.jpg
#   inflating: dev/1367.jpg
#   inflating: dev/1368.jpg
#   inflating: dev/1369.jpg
#   inflating: dev/137.jpg
#   inflating: dev/1370.jpg
#   inflating: dev/1371.jpg
#   inflating: dev/1372.jpg
#   inflating: dev/1373.jpg
#   inflating: dev/1374.jpg
#   inflating: dev/1375.jpg
#   inflating: dev/1376.jpg
#   inflating: dev/1377.jpg
#   inflating: dev/1378.jpg
#   inflating: dev/1379.jpg
#   inflating: dev/138.jpg
#   inflating: dev/1380.jpg
#   inflating: dev/1381.jpg
#   inflating: dev/1382.jpg
#   inflating: dev/1383.jpg
#   inflating: dev/1384.jpg
#   inflating: dev/1385.jpg
#   inflating: dev/1386.jpg
#   inflating: dev/1387.jpg
#   inflating: dev/1388.jpg
#   inflating: dev/1389.jpg
#   inflating: dev/139.jpg
#   inflating: dev/1390.jpg
#   inflating: dev/1391.jpg
#   inflating: dev/1392.jpg
#   inflating: dev/1393.jpg
#   inflating: dev/1394.jpg
#   inflating: dev/1395.jpg
#   inflating: dev/1396.jpg
#   inflating: dev/1397.jpg
#   inflating: dev/1398.jpg
#   inflating: dev/1399.jpg
#   inflating: dev/14.jpg
#   inflating: dev/140.jpg
#   inflating: dev/1400.jpg
#   inflating: dev/1401.jpg
#   inflating: dev/1402.jpg
#   inflating: dev/1403.jpg
#   inflating: dev/1404.jpg
#   inflating: dev/1405.jpg
#   inflating: dev/1406.jpg
#   inflating: dev/1407.jpg
#   inflating: dev/1408.jpg
#   inflating: dev/1409.jpg
#   inflating: dev/141.jpg
#   inflating: dev/1410.jpg
#   inflating: dev/1411.jpg
#   inflating: dev/1412.jpg
#   inflating: dev/1413.jpg
#   inflating: dev/1414.jpg
#   inflating: dev/1415.jpg
#   inflating: dev/1416.jpg
#   inflating: dev/1417.jpg
#   inflating: dev/1418.jpg
#   inflating: dev/1419.jpg
#   inflating: dev/142.jpg
#   inflating: dev/1420.jpg
#   inflating: dev/1421.jpg
#   inflating: dev/1422.jpg
#   inflating: dev/1423.jpg
#   inflating: dev/1424.jpg
#   inflating: dev/1425.jpg
#   inflating: dev/1426.jpg
#   inflating: dev/1427.jpg
#   inflating: dev/1428.jpg
#   inflating: dev/1429.jpg
#   inflating: dev/143.jpg
#   inflating: dev/1430.jpg
#   inflating: dev/1431.jpg
#   inflating: dev/1432.jpg
#   inflating: dev/1433.jpg
#   inflating: dev/1434.jpg
#   inflating: dev/1435.jpg
#   inflating: dev/1436.jpg
#   inflating: dev/1437.jpg
#   inflating: dev/1438.jpg
#   inflating: dev/1439.jpg
#   inflating: dev/144.jpg
#   inflating: dev/1440.jpg
#   inflating: dev/1441.jpg
#   inflating: dev/1442.jpg
#   inflating: dev/1443.jpg
#   inflating: dev/1444.jpg
#   inflating: dev/1445.jpg
#   inflating: dev/1446.jpg
#   inflating: dev/1447.jpg
#   inflating: dev/1448.jpg
#   inflating: dev/1449.jpg
#   inflating: dev/145.jpg
#   inflating: dev/1450.jpg
#   inflating: dev/1451.jpg
#   inflating: dev/1452.jpg
#   inflating: dev/1453.jpg
#   inflating: dev/1454.jpg
#   inflating: dev/1455.jpg
#   inflating: dev/1456.jpg
#   inflating: dev/1457.jpg
#   inflating: dev/1458.jpg
#   inflating: dev/1459.jpg
#   inflating: dev/146.jpg
#   inflating: dev/1460.jpg
#   inflating: dev/1461.jpg
#   inflating: dev/1462.jpg
#   inflating: dev/1463.jpg
#   inflating: dev/1464.jpg
#   inflating: dev/1465.jpg
#   inflating: dev/1466.jpg
#   inflating: dev/1467.jpg
#   inflating: dev/1468.jpg
#   inflating: dev/1469.jpg
#   inflating: dev/147.jpg
#   inflating: dev/1470.jpg
#   inflating: dev/1471.jpg
#   inflating: dev/1472.jpg
#   inflating: dev/1473.jpg
#   inflating: dev/1474.jpg
#   inflating: dev/1475.jpg
#   inflating: dev/1476.jpg
#   inflating: dev/1477.jpg
#   inflating: dev/1478.jpg
#   inflating: dev/1479.jpg
#   inflating: dev/148.jpg
#   inflating: dev/1480.jpg
#   inflating: dev/1481.jpg
#   inflating: dev/1482.jpg
#   inflating: dev/1483.jpg
#   inflating: dev/1484.jpg
#   inflating: dev/1485.jpg
#   inflating: dev/1486.jpg
#   inflating: dev/1487.jpg
#   inflating: dev/1488.jpg
#   inflating: dev/1489.jpg
#   inflating: dev/149.jpg
#   inflating: dev/1490.jpg
#   inflating: dev/1491.jpg
#   inflating: dev/1492.jpg
#   inflating: dev/1493.jpg
#   inflating: dev/1494.jpg
#   inflating: dev/1495.jpg
#   inflating: dev/1496.jpg
#   inflating: dev/1497.jpg
#   inflating: dev/1498.jpg
#   inflating: dev/1499.jpg
#   inflating: dev/15.jpg
#   inflating: dev/150.jpg
#   inflating: dev/1500.jpg
#   inflating: dev/1501.jpg
#   inflating: dev/1502.jpg
#   inflating: dev/1503.jpg
#   inflating: dev/1504.jpg
#   inflating: dev/1505.jpg
#   inflating: dev/1506.jpg
#   inflating: dev/1507.jpg
#   inflating: dev/1508.jpg
#   inflating: dev/1509.jpg
#   inflating: dev/151.jpg
#   inflating: dev/1510.jpg
#   inflating: dev/1511.jpg
#   inflating: dev/1512.jpg
#   inflating: dev/1513.jpg
#   inflating: dev/1514.jpg
#   inflating: dev/1515.jpg
#   inflating: dev/1516.jpg
#   inflating: dev/1517.jpg
#   inflating: dev/1518.jpg
#   inflating: dev/1519.jpg
#   inflating: dev/152.jpg
#   inflating: dev/1520.jpg
#   inflating: dev/1521.jpg
#   inflating: dev/1522.jpg
#   inflating: dev/1523.jpg
#   inflating: dev/1524.jpg
#   inflating: dev/1525.jpg
#   inflating: dev/1526.jpg
#   inflating: dev/1527.jpg
#   inflating: dev/1528.jpg
#   inflating: dev/1529.jpg
#   inflating: dev/153.jpg
#   inflating: dev/1530.jpg
#   inflating: dev/1531.jpg
#   inflating: dev/1532.jpg
#   inflating: dev/1533.jpg
#   inflating: dev/1534.jpg
#   inflating: dev/1535.jpg
#   inflating: dev/1536.jpg
#   inflating: dev/1537.jpg
#   inflating: dev/1538.jpg
#   inflating: dev/1539.jpg
#   inflating: dev/154.jpg
#   inflating: dev/1540.jpg
#   inflating: dev/1541.jpg
#   inflating: dev/1542.jpg
#   inflating: dev/1543.jpg
#   inflating: dev/1544.jpg
#   inflating: dev/1545.jpg
#   inflating: dev/1546.jpg
#   inflating: dev/1547.jpg
#   inflating: dev/1548.jpg
#   inflating: dev/1549.jpg
#   inflating: dev/155.jpg
#   inflating: dev/1550.jpg
#   inflating: dev/1551.jpg
#   inflating: dev/1552.jpg
#   inflating: dev/1553.jpg
#   inflating: dev/1554.jpg
#   inflating: dev/1555.jpg
#   inflating: dev/1556.jpg
#   inflating: dev/1557.jpg
#   inflating: dev/1558.jpg
#   inflating: dev/1559.jpg
#   inflating: dev/156.jpg
#   inflating: dev/1560.jpg
#   inflating: dev/1561.jpg
#   inflating: dev/1562.jpg
#   inflating: dev/1563.jpg
#   inflating: dev/1564.jpg
#   inflating: dev/1565.jpg
#   inflating: dev/1566.jpg
#   inflating: dev/1567.jpg
#   inflating: dev/1568.jpg
#   inflating: dev/1569.jpg
#   inflating: dev/157.jpg
#   inflating: dev/1570.jpg
#   inflating: dev/1571.jpg
#   inflating: dev/1572.jpg
#   inflating: dev/1573.jpg
#   inflating: dev/1574.jpg
#   inflating: dev/1575.jpg
#   inflating: dev/1576.jpg
#   inflating: dev/1577.jpg
#   inflating: dev/1578.jpg
#   inflating: dev/1579.jpg
#   inflating: dev/158.jpg
#   inflating: dev/1580.jpg
#   inflating: dev/1581.jpg
#   inflating: dev/1582.jpg
#   inflating: dev/1583.jpg
#   inflating: dev/1584.jpg
#   inflating: dev/1585.jpg
#   inflating: dev/1586.jpg
#   inflating: dev/1587.jpg
#   inflating: dev/1588.jpg
#   inflating: dev/1589.jpg
#   inflating: dev/159.jpg
#   inflating: dev/1590.jpg
#   inflating: dev/1591.jpg
#   inflating: dev/1592.jpg
#   inflating: dev/1593.jpg
#   inflating: dev/1594.jpg
#   inflating: dev/1595.jpg
#   inflating: dev/1596.jpg
#   inflating: dev/1597.jpg
#   inflating: dev/1598.jpg
#   inflating: dev/1599.jpg
#   inflating: dev/16.jpg
#   inflating: dev/160.jpg
#   inflating: dev/1600.jpg
#   inflating: dev/1601.jpg
#   inflating: dev/1602.jpg
#   inflating: dev/1603.jpg
#   inflating: dev/1604.jpg
#   inflating: dev/1605.jpg
#   inflating: dev/1606.jpg
#   inflating: dev/1607.jpg
#   inflating: dev/1608.jpg
#   inflating: dev/1609.jpg
#   inflating: dev/161.jpg
#   inflating: dev/1610.jpg
#   inflating: dev/1611.jpg
#   inflating: dev/1612.jpg
#   inflating: dev/1613.jpg
#   inflating: dev/1614.jpg
#   inflating: dev/1615.jpg
#   inflating: dev/1616.jpg
#   inflating: dev/1617.jpg
#   inflating: dev/1618.jpg
#   inflating: dev/1619.jpg
#   inflating: dev/162.jpg
#   inflating: dev/1620.jpg
#   inflating: dev/1621.jpg
#   inflating: dev/1622.jpg
#   inflating: dev/1623.jpg
#   inflating: dev/1624.jpg
#   inflating: dev/1625.jpg
#   inflating: dev/1626.jpg
#   inflating: dev/1627.jpg
#   inflating: dev/1628.jpg
#   inflating: dev/1629.jpg
#   inflating: dev/163.jpg
#   inflating: dev/1630.jpg
#   inflating: dev/1631.jpg
#   inflating: dev/1632.jpg
#   inflating: dev/1633.jpg
#   inflating: dev/1634.jpg
#   inflating: dev/1635.jpg
#   inflating: dev/1636.jpg
#   inflating: dev/1637.jpg
#   inflating: dev/1638.jpg
#   inflating: dev/1639.jpg
#   inflating: dev/164.jpg
#   inflating: dev/1640.jpg
#   inflating: dev/1641.jpg
#   inflating: dev/1642.jpg
#   inflating: dev/1643.jpg
#   inflating: dev/1644.jpg
#   inflating: dev/1645.jpg
#   inflating: dev/1646.jpg
#   inflating: dev/1647.jpg
#   inflating: dev/1648.jpg
#   inflating: dev/1649.jpg
#   inflating: dev/165.jpg
#   inflating: dev/1650.jpg
#   inflating: dev/1651.jpg
#   inflating: dev/1652.jpg
#   inflating: dev/1653.jpg
#   inflating: dev/1654.jpg
#   inflating: dev/1655.jpg
#   inflating: dev/1656.jpg
#   inflating: dev/1657.jpg
#   inflating: dev/1658.jpg
#   inflating: dev/1659.jpg
#   inflating: dev/166.jpg
#   inflating: dev/1660.jpg
#   inflating: dev/1661.jpg
#   inflating: dev/1662.jpg
#   inflating: dev/1663.jpg
#   inflating: dev/1664.jpg
#   inflating: dev/1665.jpg
#   inflating: dev/1666.jpg
#   inflating: dev/1667.jpg
#   inflating: dev/1668.jpg
#   inflating: dev/1669.jpg
#   inflating: dev/167.jpg
#   inflating: dev/1670.jpg
#   inflating: dev/1671.jpg
#   inflating: dev/1672.jpg
#   inflating: dev/1673.jpg
#   inflating: dev/1674.jpg
#   inflating: dev/1675.jpg
#   inflating: dev/1676.jpg
#   inflating: dev/1677.jpg
#   inflating: dev/1678.jpg
#   inflating: dev/1679.jpg
#   inflating: dev/168.jpg
#   inflating: dev/1680.jpg
#   inflating: dev/1681.jpg
#   inflating: dev/1682.jpg
#   inflating: dev/1683.jpg
#   inflating: dev/1684.jpg
#   inflating: dev/1685.jpg
#   inflating: dev/1686.jpg
#   inflating: dev/1687.jpg
#   inflating: dev/1688.jpg
#   inflating: dev/1689.jpg
#   inflating: dev/169.jpg
#   inflating: dev/1690.jpg
#   inflating: dev/1691.jpg
#   inflating: dev/1692.jpg
#   inflating: dev/1693.jpg
#   inflating: dev/1694.jpg
#   inflating: dev/1695.jpg
#   inflating: dev/1696.jpg
#   inflating: dev/1697.jpg
#   inflating: dev/1698.jpg
#   inflating: dev/1699.jpg
#   inflating: dev/17.jpg
#   inflating: dev/170.jpg
#   inflating: dev/1700.jpg
#   inflating: dev/1701.jpg
#   inflating: dev/1702.jpg
#   inflating: dev/1703.jpg
#   inflating: dev/1704.jpg
#   inflating: dev/1705.jpg
#   inflating: dev/1706.jpg
#   inflating: dev/1707.jpg
#   inflating: dev/1708.jpg
#   inflating: dev/1709.jpg
#   inflating: dev/171.jpg
#   inflating: dev/1710.jpg
#   inflating: dev/1711.jpg
#   inflating: dev/1712.jpg
#   inflating: dev/1713.jpg
#   inflating: dev/1714.jpg
#   inflating: dev/1715.jpg
#   inflating: dev/1716.jpg
#   inflating: dev/1717.jpg
#   inflating: dev/1718.jpg
#   inflating: dev/1719.jpg
#   inflating: dev/172.jpg
#   inflating: dev/1720.jpg
#   inflating: dev/1721.jpg
#   inflating: dev/1722.jpg
#   inflating: dev/1723.jpg
#   inflating: dev/1724.jpg
#   inflating: dev/1725.jpg
#   inflating: dev/1726.jpg
#   inflating: dev/1727.jpg
#   inflating: dev/1728.jpg
#   inflating: dev/1729.jpg
#   inflating: dev/173.jpg
#   inflating: dev/1730.jpg
#   inflating: dev/1731.jpg
#   inflating: dev/1732.jpg
#   inflating: dev/1733.jpg
#   inflating: dev/1734.jpg
#   inflating: dev/1735.jpg
#   inflating: dev/1736.jpg
#   inflating: dev/1737.jpg
#   inflating: dev/1738.jpg
#   inflating: dev/1739.jpg
#   inflating: dev/174.jpg
#   inflating: dev/1740.jpg
#   inflating: dev/1741.jpg
#   inflating: dev/1742.jpg
#   inflating: dev/1743.jpg
#   inflating: dev/1744.jpg
#   inflating: dev/1745.jpg
#   inflating: dev/1746.jpg
#   inflating: dev/1747.jpg
#   inflating: dev/1748.jpg
#   inflating: dev/1749.jpg
#   inflating: dev/175.jpg
#   inflating: dev/1750.jpg
#   inflating: dev/1751.jpg
#   inflating: dev/1752.jpg
#   inflating: dev/1753.jpg
#   inflating: dev/1754.jpg
#   inflating: dev/1755.jpg
#   inflating: dev/1756.jpg
#   inflating: dev/1757.jpg
#   inflating: dev/1758.jpg
#   inflating: dev/1759.jpg
#   inflating: dev/176.jpg
#   inflating: dev/1760.jpg
#   inflating: dev/1761.jpg
#   inflating: dev/1762.jpg
#   inflating: dev/1763.jpg
#   inflating: dev/1764.jpg
#   inflating: dev/1765.jpg
#   inflating: dev/1766.jpg
#   inflating: dev/1767.jpg
#   inflating: dev/1768.jpg
#   inflating: dev/1769.jpg
#   inflating: dev/177.jpg
#   inflating: dev/1770.jpg
#   inflating: dev/1771.jpg
#   inflating: dev/1772.jpg
#   inflating: dev/1773.jpg
#   inflating: dev/1774.jpg
#   inflating: dev/1775.jpg
#   inflating: dev/1776.jpg
#   inflating: dev/1777.jpg
#   inflating: dev/1778.jpg
#   inflating: dev/1779.jpg
#   inflating: dev/178.jpg
#   inflating: dev/1780.jpg
#   inflating: dev/1781.jpg
#   inflating: dev/1782.jpg
#   inflating: dev/1783.jpg
#   inflating: dev/1784.jpg
#   inflating: dev/1785.jpg
#   inflating: dev/1786.jpg
#   inflating: dev/1787.jpg
#   inflating: dev/1788.jpg
#   inflating: dev/1789.jpg
#   inflating: dev/179.jpg
#   inflating: dev/1790.jpg
#   inflating: dev/1791.jpg
#   inflating: dev/1792.jpg
#   inflating: dev/1793.jpg
#   inflating: dev/1794.jpg
#   inflating: dev/1795.jpg
#   inflating: dev/1796.jpg
#   inflating: dev/1797.jpg
#   inflating: dev/1798.jpg
#   inflating: dev/1799.jpg
#   inflating: dev/18.jpg
#   inflating: dev/180.jpg
#   inflating: dev/1800.jpg
#   inflating: dev/1801.jpg
#   inflating: dev/1802.jpg
#   inflating: dev/1803.jpg
#   inflating: dev/1804.jpg
#   inflating: dev/1805.jpg
#   inflating: dev/1806.jpg
#   inflating: dev/1807.jpg
#   inflating: dev/1808.jpg
#   inflating: dev/1809.jpg
#   inflating: dev/181.jpg
#   inflating: dev/1810.jpg
#   inflating: dev/1811.jpg
#   inflating: dev/1812.jpg
#   inflating: dev/1813.jpg
#   inflating: dev/1814.jpg
#   inflating: dev/1815.jpg
#   inflating: dev/1816.jpg
#   inflating: dev/1817.jpg
#   inflating: dev/1818.jpg
#   inflating: dev/1819.jpg
#   inflating: dev/182.jpg
#   inflating: dev/1820.jpg
#   inflating: dev/1821.jpg
#   inflating: dev/1822.jpg
#   inflating: dev/1823.jpg
#   inflating: dev/1824.jpg
#   inflating: dev/1825.jpg
#   inflating: dev/1826.jpg
#   inflating: dev/1827.jpg
#   inflating: dev/1828.jpg
#   inflating: dev/1829.jpg
#   inflating: dev/183.jpg
#   inflating: dev/1830.jpg
#   inflating: dev/1831.jpg
#   inflating: dev/1832.jpg
#   inflating: dev/1833.jpg
#   inflating: dev/1834.jpg
#   inflating: dev/1835.jpg
#   inflating: dev/1836.jpg
#   inflating: dev/1837.jpg
#   inflating: dev/1838.jpg
#   inflating: dev/1839.jpg
#   inflating: dev/184.jpg
#   inflating: dev/1840.jpg
#   inflating: dev/1841.jpg
#   inflating: dev/1842.jpg
#   inflating: dev/1843.jpg
#   inflating: dev/1844.jpg
#   inflating: dev/1845.jpg
#   inflating: dev/1846.jpg
#   inflating: dev/1847.jpg
#   inflating: dev/1848.jpg
#   inflating: dev/1849.jpg
#   inflating: dev/185.jpg
#   inflating: dev/1850.jpg
#   inflating: dev/1851.jpg
#   inflating: dev/1852.jpg
#   inflating: dev/1853.jpg
#   inflating: dev/1854.jpg
#   inflating: dev/1855.jpg
#   inflating: dev/1856.jpg
#   inflating: dev/1857.jpg
#   inflating: dev/1858.jpg
#   inflating: dev/1859.jpg
#   inflating: dev/186.jpg
#   inflating: dev/1860.jpg
#   inflating: dev/1861.jpg
#   inflating: dev/1862.jpg
#   inflating: dev/1863.jpg
#   inflating: dev/1864.jpg
#   inflating: dev/1865.jpg
#   inflating: dev/1866.jpg
#   inflating: dev/1867.jpg
#   inflating: dev/1868.jpg
#   inflating: dev/1869.jpg
#   inflating: dev/187.jpg
#   inflating: dev/1870.jpg
#   inflating: dev/1871.jpg
#   inflating: dev/1872.jpg
#   inflating: dev/1873.jpg
#   inflating: dev/1874.jpg
#   inflating: dev/1875.jpg
#   inflating: dev/1876.jpg
#   inflating: dev/1877.jpg
#   inflating: dev/1878.jpg
#   inflating: dev/1879.jpg
#   inflating: dev/188.jpg
#   inflating: dev/1880.jpg
#   inflating: dev/1881.jpg
#   inflating: dev/1882.jpg
#   inflating: dev/1883.jpg
#   inflating: dev/1884.jpg
#   inflating: dev/1885.jpg
#   inflating: dev/1886.jpg
#   inflating: dev/1887.jpg
#   inflating: dev/1888.jpg
#   inflating: dev/1889.jpg
#   inflating: dev/189.jpg
#   inflating: dev/1890.jpg
#   inflating: dev/1891.jpg
#   inflating: dev/1892.jpg
#   inflating: dev/1893.jpg
#   inflating: dev/1894.jpg
#   inflating: dev/1895.jpg
#   inflating: dev/1896.jpg
#   inflating: dev/1897.jpg
#   inflating: dev/1898.jpg
#   inflating: dev/1899.jpg
#   inflating: dev/19.jpg
#   inflating: dev/190.jpg
#   inflating: dev/1900.jpg
#   inflating: dev/1901.jpg
#   inflating: dev/1902.jpg
#   inflating: dev/1903.jpg
#   inflating: dev/1904.jpg
#   inflating: dev/1905.jpg
#   inflating: dev/1906.jpg
#   inflating: dev/1907.jpg
#   inflating: dev/1908.jpg
#   inflating: dev/1909.jpg
#   inflating: dev/191.jpg
#   inflating: dev/1910.jpg
#   inflating: dev/1911.jpg
#   inflating: dev/1912.jpg
#   inflating: dev/1913.jpg
#   inflating: dev/1914.jpg
#   inflating: dev/1915.jpg
#   inflating: dev/1916.jpg
#   inflating: dev/1917.jpg
#   inflating: dev/1918.jpg
#   inflating: dev/1919.jpg
#   inflating: dev/192.jpg
#   inflating: dev/1920.jpg
#   inflating: dev/1921.jpg
#   inflating: dev/1922.jpg
#   inflating: dev/1923.jpg
#   inflating: dev/1924.jpg
#   inflating: dev/1925.jpg
#   inflating: dev/1926.jpg
#   inflating: dev/1927.jpg
#   inflating: dev/1928.jpg
#   inflating: dev/1929.jpg
#   inflating: dev/193.jpg
#   inflating: dev/1930.jpg
#   inflating: dev/1931.jpg
#   inflating: dev/1932.jpg
#   inflating: dev/1933.jpg
#   inflating: dev/1934.jpg
#   inflating: dev/1935.jpg
#   inflating: dev/1936.jpg
#   inflating: dev/1937.jpg
#   inflating: dev/1938.jpg
#   inflating: dev/1939.jpg
#   inflating: dev/194.jpg
#   inflating: dev/1940.jpg
#   inflating: dev/1941.jpg
#   inflating: dev/1942.jpg
#   inflating: dev/1943.jpg
#   inflating: dev/1944.jpg
#   inflating: dev/1945.jpg
#   inflating: dev/1946.jpg
#   inflating: dev/1947.jpg
#   inflating: dev/1948.jpg
#   inflating: dev/1949.jpg
#   inflating: dev/195.jpg
#   inflating: dev/1950.jpg
#   inflating: dev/1951.jpg
#   inflating: dev/1952.jpg
#   inflating: dev/1953.jpg
#   inflating: dev/1954.jpg
#   inflating: dev/1955.jpg
#   inflating: dev/1956.jpg
#   inflating: dev/1957.jpg
#   inflating: dev/1958.jpg
#   inflating: dev/1959.jpg
#   inflating: dev/196.jpg
#   inflating: dev/1960.jpg
#   inflating: dev/1961.jpg
#   inflating: dev/1962.jpg
#   inflating: dev/1963.jpg
#   inflating: dev/1964.jpg
#   inflating: dev/1965.jpg
#   inflating: dev/1966.jpg
#   inflating: dev/1967.jpg
#   inflating: dev/1968.jpg
#   inflating: dev/1969.jpg
#   inflating: dev/197.jpg
#   inflating: dev/1970.jpg
#   inflating: dev/1971.jpg
#   inflating: dev/1972.jpg
#   inflating: dev/1973.jpg
#   inflating: dev/1974.jpg
#   inflating: dev/1975.jpg
#   inflating: dev/1976.jpg
#   inflating: dev/1977.jpg
#   inflating: dev/1978.jpg
#   inflating: dev/1979.jpg
#   inflating: dev/198.jpg
#   inflating: dev/1980.jpg
#   inflating: dev/1981.jpg
#   inflating: dev/1982.jpg
#   inflating: dev/1983.jpg
#   inflating: dev/1984.jpg
#   inflating: dev/1985.jpg
#   inflating: dev/1986.jpg
#   inflating: dev/1987.jpg
#   inflating: dev/1988.jpg
#   inflating: dev/1989.jpg
#   inflating: dev/199.jpg
#   inflating: dev/1990.jpg
#   inflating: dev/1991.jpg
#   inflating: dev/1992.jpg
#   inflating: dev/1993.jpg
#   inflating: dev/1994.jpg
#   inflating: dev/1995.jpg
#   inflating: dev/1996.jpg
#   inflating: dev/1997.jpg
#   inflating: dev/1998.jpg
#   inflating: dev/1999.jpg
#   inflating: dev/2.jpg
#   inflating: dev/20.jpg
#   inflating: dev/200.jpg
#   inflating: dev/2000.jpg
#   inflating: dev/2001.jpg
#   inflating: dev/2002.jpg
#   inflating: dev/2003.jpg
#   inflating: dev/2004.jpg
#   inflating: dev/2005.jpg
#   inflating: dev/2006.jpg
#   inflating: dev/2007.jpg
#   inflating: dev/2008.jpg
#   inflating: dev/2009.jpg
#   inflating: dev/201.jpg
#   inflating: dev/2010.jpg
#   inflating: dev/2011.jpg
#   inflating: dev/2012.jpg
#   inflating: dev/2013.jpg
#   inflating: dev/2014.jpg
#   inflating: dev/2015.jpg
#   inflating: dev/2016.jpg
#   inflating: dev/2017.jpg
#   inflating: dev/2018.jpg
#   inflating: dev/2019.jpg
#   inflating: dev/202.jpg
#   inflating: dev/2020.jpg
#   inflating: dev/2021.jpg
#   inflating: dev/2022.jpg
#   inflating: dev/2023.jpg
#   inflating: dev/2024.jpg
#   inflating: dev/2025.jpg
#   inflating: dev/2026.jpg
#   inflating: dev/2027.jpg
#   inflating: dev/2028.jpg
#   inflating: dev/2029.jpg
#   inflating: dev/203.jpg
#   inflating: dev/2030.jpg
#   inflating: dev/2031.jpg
#   inflating: dev/2032.jpg
#   inflating: dev/2033.jpg
#   inflating: dev/2034.jpg
#   inflating: dev/2035.jpg
#   inflating: dev/2036.jpg
#   inflating: dev/2037.jpg
#   inflating: dev/2038.jpg
#   inflating: dev/2039.jpg
#   inflating: dev/204.jpg
#   inflating: dev/2040.jpg
#   inflating: dev/2041.jpg
#   inflating: dev/2042.jpg
#   inflating: dev/2043.jpg
#   inflating: dev/2044.jpg
#   inflating: dev/2045.jpg
#   inflating: dev/2046.jpg
#   inflating: dev/2047.jpg
#   inflating: dev/2048.jpg
#   inflating: dev/2049.jpg
#   inflating: dev/205.jpg
#   inflating: dev/2050.jpg
#   inflating: dev/2051.jpg
#   inflating: dev/2052.jpg
#   inflating: dev/2053.jpg
#   inflating: dev/2054.jpg
#   inflating: dev/2055.jpg
#   inflating: dev/2056.jpg
#   inflating: dev/2057.jpg
#   inflating: dev/2058.jpg
#   inflating: dev/2059.jpg
#   inflating: dev/206.jpg
#   inflating: dev/2060.jpg
#   inflating: dev/2061.jpg
#   inflating: dev/2062.jpg
#   inflating: dev/2063.jpg
#   inflating: dev/2064.jpg
#   inflating: dev/2065.jpg
#   inflating: dev/2066.jpg
#   inflating: dev/2067.jpg
#   inflating: dev/2068.jpg
#   inflating: dev/2069.jpg
#   inflating: dev/207.jpg
#   inflating: dev/2070.jpg
#   inflating: dev/2071.jpg
#   inflating: dev/2072.jpg
#   inflating: dev/2073.jpg
#   inflating: dev/2074.jpg
#   inflating: dev/2075.jpg
#   inflating: dev/2076.jpg
#   inflating: dev/2077.jpg
#   inflating: dev/2078.jpg
#   inflating: dev/2079.jpg
#   inflating: dev/208.jpg
#   inflating: dev/2080.jpg
#   inflating: dev/2081.jpg
#   inflating: dev/2082.jpg
#   inflating: dev/2083.jpg
#   inflating: dev/2084.jpg
#   inflating: dev/2085.jpg
#   inflating: dev/2086.jpg
#   inflating: dev/2087.jpg
#   inflating: dev/2088.jpg
#   inflating: dev/2089.jpg
#   inflating: dev/209.jpg
#   inflating: dev/2090.jpg
#   inflating: dev/2091.jpg
#   inflating: dev/2092.jpg
#   inflating: dev/2093.jpg
#   inflating: dev/2094.jpg
#   inflating: dev/2095.jpg
#   inflating: dev/2096.jpg
#   inflating: dev/2097.jpg
#   inflating: dev/2098.jpg
#   inflating: dev/2099.jpg
#   inflating: dev/21.jpg
#   inflating: dev/210.jpg
#   inflating: dev/2100.jpg
#   inflating: dev/2101.jpg
#   inflating: dev/2102.jpg
#   inflating: dev/2103.jpg
#   inflating: dev/2104.jpg
#   inflating: dev/2105.jpg
#   inflating: dev/2106.jpg
#   inflating: dev/2107.jpg
#   inflating: dev/2108.jpg
#   inflating: dev/2109.jpg
#   inflating: dev/211.jpg
#   inflating: dev/2110.jpg
#   inflating: dev/2111.jpg
#   inflating: dev/2112.jpg
#   inflating: dev/2113.jpg
#   inflating: dev/2114.jpg
#   inflating: dev/2115.jpg
#   inflating: dev/2116.jpg
#   inflating: dev/2117.jpg
#   inflating: dev/2118.jpg
#   inflating: dev/2119.jpg
#   inflating: dev/212.jpg
#   inflating: dev/2120.jpg
#   inflating: dev/2121.jpg
#   inflating: dev/2122.jpg
#   inflating: dev/2123.jpg
#   inflating: dev/2124.jpg
#   inflating: dev/2125.jpg
#   inflating: dev/2126.jpg
#   inflating: dev/2127.jpg
#   inflating: dev/2128.jpg
#   inflating: dev/2129.jpg
#   inflating: dev/213.jpg
#   inflating: dev/2130.jpg
#   inflating: dev/2131.jpg
#   inflating: dev/2132.jpg
#   inflating: dev/2133.jpg
#   inflating: dev/2134.jpg
#   inflating: dev/2135.jpg
#   inflating: dev/2136.jpg
#   inflating: dev/2137.jpg
#   inflating: dev/2138.jpg
#   inflating: dev/2139.jpg
#   inflating: dev/214.jpg
#   inflating: dev/2140.jpg
#   inflating: dev/2141.jpg
#   inflating: dev/2142.jpg
#   inflating: dev/2143.jpg
#   inflating: dev/2144.jpg
#   inflating: dev/2145.jpg
#   inflating: dev/2146.jpg
#   inflating: dev/2147.jpg
#   inflating: dev/2148.jpg
#   inflating: dev/2149.jpg
#   inflating: dev/215.jpg
#   inflating: dev/2150.jpg
#   inflating: dev/2151.jpg
#   inflating: dev/2152.jpg
#   inflating: dev/2153.jpg
#   inflating: dev/2154.jpg
#   inflating: dev/2155.jpg
#   inflating: dev/2156.jpg
#   inflating: dev/2157.jpg
#   inflating: dev/2158.jpg
#   inflating: dev/2159.jpg
#   inflating: dev/216.jpg
#   inflating: dev/2160.jpg
#   inflating: dev/2161.jpg
#   inflating: dev/2162.jpg
#   inflating: dev/2163.jpg
#   inflating: dev/2164.jpg
#   inflating: dev/2165.jpg
#   inflating: dev/2166.jpg
#   inflating: dev/2167.jpg
#   inflating: dev/2168.jpg
#   inflating: dev/2169.jpg
#   inflating: dev/217.jpg
#   inflating: dev/2170.jpg
#   inflating: dev/2171.jpg
#   inflating: dev/2172.jpg
#   inflating: dev/2173.jpg
#   inflating: dev/2174.jpg
#   inflating: dev/2175.jpg
#   inflating: dev/2176.jpg
#   inflating: dev/2177.jpg
#   inflating: dev/2178.jpg
#   inflating: dev/2179.jpg
#   inflating: dev/218.jpg
#   inflating: dev/2180.jpg
#   inflating: dev/2181.jpg
#   inflating: dev/2182.jpg
#   inflating: dev/2183.jpg
#   inflating: dev/2184.jpg
#   inflating: dev/2185.jpg
#   inflating: dev/2186.jpg
#   inflating: dev/2187.jpg
#   inflating: dev/2188.jpg
#   inflating: dev/2189.jpg
# ...
#   inflating: dev/62.jpg
#   inflating: dev/620.jpg
#   inflating: dev/621.jpg
#   inflating: dev/622.jpg
#   inflating: dev/623.jpg
#   inflating: dev/624.jpg
#   inflating: dev/625.jpg
#   inflating: dev/626.jpg
#   inflating: dev/627.jpg
#   inflating: dev/628.jpg
#   inflating: dev/629.jpg
#   inflating: dev/63.jpg
#   inflating: dev/630.jpg
#   inflating: dev/631.jpg
#   inflating: dev/632.jpg
#   inflating: dev/633.jpg
#   inflating: dev/634.jpg
#   inflating: dev/635.jpg
#   inflating: dev/636.jpg
#   inflating: dev/637.jpg
#   inflating: dev/638.jpg
#   inflating: dev/639.jpg
#   inflating: dev/64.jpg
#   inflating: dev/640.jpg
#   inflating: dev/641.jpg
#   inflating: dev/642.jpg
#   inflating: dev/643.jpg
#   inflating: dev/644.jpg
#   inflating: dev/645.jpg
#   inflating: dev/646.jpg
#   inflating: dev/647.jpg
#   inflating: dev/648.jpg
#   inflating: dev/649.jpg
#   inflating: dev/65.jpg
#   inflating: dev/650.jpg
#   inflating: dev/651.jpg
#   inflating: dev/652.jpg
#   inflating: dev/653.jpg
#   inflating: dev/654.jpg
#   inflating: dev/655.jpg
#   inflating: dev/656.jpg
#   inflating: dev/657.jpg
#   inflating: dev/658.jpg
#   inflating: dev/659.jpg
#   inflating: dev/66.jpg
#   inflating: dev/660.jpg
#   inflating: dev/661.jpg
#   inflating: dev/662.jpg
#   inflating: dev/663.jpg
#   inflating: dev/664.jpg
#   inflating: dev/665.jpg
#   inflating: dev/666.jpg
#   inflating: dev/667.jpg
#   inflating: dev/668.jpg
#   inflating: dev/669.jpg
#   inflating: dev/67.jpg
#   inflating: dev/670.jpg
#   inflating: dev/671.jpg
#   inflating: dev/672.jpg
#   inflating: dev/673.jpg
#   inflating: dev/674.jpg
#   inflating: dev/675.jpg
#   inflating: dev/676.jpg
#   inflating: dev/677.jpg
#   inflating: dev/678.jpg
#   inflating: dev/679.jpg
#   inflating: dev/68.jpg
#   inflating: dev/680.jpg
#   inflating: dev/681.jpg
#   inflating: dev/682.jpg
#   inflating: dev/683.jpg
#   inflating: dev/684.jpg
#   inflating: dev/685.jpg
#   inflating: dev/686.jpg
#   inflating: dev/687.jpg
#   inflating: dev/688.jpg
#   inflating: dev/689.jpg
#   inflating: dev/69.jpg
#   inflating: dev/690.jpg
#   inflating: dev/691.jpg
#   inflating: dev/692.jpg
#   inflating: dev/693.jpg
#   inflating: dev/694.jpg
#   inflating: dev/695.jpg
#   inflating: dev/696.jpg
#   inflating: dev/697.jpg
#   inflating: dev/698.jpg
#   inflating: dev/699.jpg
#   inflating: dev/7.jpg
#   inflating: dev/70.jpg
#   inflating: dev/700.jpg
#   inflating: dev/701.jpg
#   inflating: dev/702.jpg
#   inflating: dev/703.jpg
#   inflating: dev/704.jpg
#   inflating: dev/705.jpg
#   inflating: dev/706.jpg
#   inflating: dev/707.jpg
#   inflating: dev/708.jpg
#   inflating: dev/709.jpg
#   inflating: dev/71.jpg
#   inflating: dev/710.jpg
#   inflating: dev/711.jpg
#   inflating: dev/712.jpg
#   inflating: dev/713.jpg
#   inflating: dev/714.jpg
#   inflating: dev/715.jpg
#   inflating: dev/716.jpg
#   inflating: dev/717.jpg
#   inflating: dev/718.jpg
#   inflating: dev/719.jpg
#   inflating: dev/72.jpg
#   inflating: dev/720.jpg
#   inflating: dev/721.jpg
#   inflating: dev/722.jpg
#   inflating: dev/723.jpg
#   inflating: dev/724.jpg
#   inflating: dev/725.jpg
#   inflating: dev/726.jpg
#   inflating: dev/727.jpg
#   inflating: dev/728.jpg
#   inflating: dev/729.jpg
#   inflating: dev/73.jpg
#   inflating: dev/730.jpg
#   inflating: dev/731.jpg
#   inflating: dev/732.jpg
#   inflating: dev/733.jpg
#   inflating: dev/734.jpg
#   inflating: dev/735.jpg
#   inflating: dev/736.jpg
#   inflating: dev/737.jpg
#   inflating: dev/738.jpg
#   inflating: dev/739.jpg
#   inflating: dev/74.jpg
#   inflating: dev/740.jpg
#   inflating: dev/741.jpg
#   inflating: dev/742.jpg
#   inflating: dev/743.jpg
#   inflating: dev/744.jpg
#   inflating: dev/745.jpg
#   inflating: dev/746.jpg
#   inflating: dev/747.jpg
#   inflating: dev/748.jpg
#   inflating: dev/749.jpg
#   inflating: dev/75.jpg
#   inflating: dev/750.jpg
#   inflating: dev/751.jpg
#   inflating: dev/752.jpg
#   inflating: dev/753.jpg
#   inflating: dev/754.jpg
#   inflating: dev/755.jpg
#   inflating: dev/756.jpg
#   inflating: dev/757.jpg
#   inflating: dev/758.jpg
#   inflating: dev/759.jpg
#   inflating: dev/76.jpg
#   inflating: dev/760.jpg
#   inflating: dev/761.jpg
#   inflating: dev/762.jpg
#   inflating: dev/763.jpg
#   inflating: dev/764.jpg
#   inflating: dev/765.jpg
#   inflating: dev/766.jpg
#   inflating: dev/767.jpg
#   inflating: dev/768.jpg
#   inflating: dev/769.jpg
#   inflating: dev/77.jpg
#   inflating: dev/770.jpg
#   inflating: dev/771.jpg
#   inflating: dev/772.jpg
#   inflating: dev/773.jpg
#   inflating: dev/774.jpg
#   inflating: dev/775.jpg
#   inflating: dev/776.jpg
#   inflating: dev/777.jpg
#   inflating: dev/778.jpg
#   inflating: dev/779.jpg
#   inflating: dev/78.jpg
#   inflating: dev/780.jpg
#   inflating: dev/781.jpg
#   inflating: dev/782.jpg
#   inflating: dev/783.jpg
#   inflating: dev/784.jpg
#   inflating: dev/785.jpg
#   inflating: dev/786.jpg
#   inflating: dev/787.jpg
#   inflating: dev/788.jpg
#   inflating: dev/789.jpg
#   inflating: dev/79.jpg
#   inflating: dev/790.jpg
#   inflating: dev/791.jpg
#   inflating: dev/792.jpg
#   inflating: dev/793.jpg
#   inflating: dev/794.jpg
#   inflating: dev/795.jpg
#   inflating: dev/796.jpg
#   inflating: dev/797.jpg
#   inflating: dev/798.jpg
#   inflating: dev/799.jpg
#   inflating: dev/8.jpg
#   inflating: dev/80.jpg
#   inflating: dev/800.jpg
#   inflating: dev/801.jpg
#   inflating: dev/802.jpg
#   inflating: dev/803.jpg
#   inflating: dev/804.jpg
#   inflating: dev/805.jpg
#   inflating: dev/806.jpg
#   inflating: dev/807.jpg
#   inflating: dev/808.jpg
#   inflating: dev/809.jpg
#   inflating: dev/81.jpg
#   inflating: dev/810.jpg
#   inflating: dev/811.jpg
#   inflating: dev/812.jpg
#   inflating: dev/813.jpg
#   inflating: dev/814.jpg
#   inflating: dev/815.jpg
#   inflating: dev/816.jpg
#   inflating: dev/817.jpg
#   inflating: dev/818.jpg
#   inflating: dev/819.jpg
#   inflating: dev/82.jpg
#   inflating: dev/820.jpg
#   inflating: dev/821.jpg
#   inflating: dev/822.jpg
#   inflating: dev/823.jpg
#   inflating: dev/824.jpg
#   inflating: dev/825.jpg
#   inflating: dev/826.jpg
#   inflating: dev/827.jpg
#   inflating: dev/828.jpg
#   inflating: dev/829.jpg
#   inflating: dev/83.jpg
#   inflating: dev/830.jpg
#   inflating: dev/831.jpg
#   inflating: dev/832.jpg
#   inflating: dev/833.jpg
#   inflating: dev/834.jpg
#   inflating: dev/835.jpg
#   inflating: dev/836.jpg
#   inflating: dev/837.jpg
#   inflating: dev/838.jpg
#   inflating: dev/839.jpg
#   inflating: dev/84.jpg
#   inflating: dev/840.jpg
#   inflating: dev/841.jpg
#   inflating: dev/842.jpg
#   inflating: dev/843.jpg
#   inflating: dev/844.jpg
#   inflating: dev/845.jpg
#   inflating: dev/846.jpg
#   inflating: dev/847.jpg
#   inflating: dev/848.jpg
#   inflating: dev/849.jpg
#   inflating: dev/85.jpg
#   inflating: dev/850.jpg
#   inflating: dev/851.jpg
#   inflating: dev/852.jpg
#   inflating: dev/853.jpg
#   inflating: dev/854.jpg
#   inflating: dev/855.jpg
#   inflating: dev/856.jpg
#   inflating: dev/857.jpg
#   inflating: dev/858.jpg
#   inflating: dev/859.jpg
#   inflating: dev/86.jpg
#   inflating: dev/860.jpg
#   inflating: dev/861.jpg
#   inflating: dev/862.jpg
#   inflating: dev/863.jpg
#   inflating: dev/864.jpg
#   inflating: dev/865.jpg
#   inflating: dev/866.jpg
#   inflating: dev/867.jpg
#   inflating: dev/868.jpg
#   inflating: dev/869.jpg
#   inflating: dev/87.jpg
#   inflating: dev/870.jpg
#   inflating: dev/871.jpg
#   inflating: dev/872.jpg
#   inflating: dev/873.jpg
#   inflating: dev/874.jpg
#   inflating: dev/875.jpg
#   inflating: dev/876.jpg
#   inflating: dev/877.jpg
#   inflating: dev/878.jpg
#   inflating: dev/879.jpg
#   inflating: dev/88.jpg
#   inflating: dev/880.jpg
#   inflating: dev/881.jpg
#   inflating: dev/882.jpg
#   inflating: dev/883.jpg
#   inflating: dev/884.jpg
#   inflating: dev/885.jpg
#   inflating: dev/886.jpg
#   inflating: dev/887.jpg
#   inflating: dev/888.jpg
#   inflating: dev/889.jpg
#   inflating: dev/89.jpg
#   inflating: dev/890.jpg
#   inflating: dev/891.jpg
#   inflating: dev/892.jpg
#   inflating: dev/893.jpg
#   inflating: dev/894.jpg
#   inflating: dev/895.jpg
#   inflating: dev/896.jpg
#   inflating: dev/897.jpg
#   inflating: dev/898.jpg
#   inflating: dev/899.jpg
#   inflating: dev/9.jpg
#   inflating: dev/90.jpg
#   inflating: dev/900.jpg
#   inflating: dev/901.jpg
#   inflating: dev/902.jpg
#   inflating: dev/903.jpg
#   inflating: dev/904.jpg
#   inflating: dev/905.jpg
#   inflating: dev/906.jpg
#   inflating: dev/907.jpg
#   inflating: dev/908.jpg
#   inflating: dev/909.jpg
#   inflating: dev/91.jpg
#   inflating: dev/910.jpg
#   inflating: dev/911.jpg
#   inflating: dev/912.jpg
#   inflating: dev/913.jpg
#   inflating: dev/914.jpg
#   inflating: dev/915.jpg
#   inflating: dev/916.jpg
#   inflating: dev/917.jpg
#   inflating: dev/918.jpg
#   inflating: dev/919.jpg
#   inflating: dev/92.jpg
#   inflating: dev/920.jpg
#   inflating: dev/921.jpg
#   inflating: dev/922.jpg
#   inflating: dev/923.jpg
#   inflating: dev/924.jpg
#   inflating: dev/925.jpg
#   inflating: dev/926.jpg
#   inflating: dev/927.jpg
#   inflating: dev/928.jpg
#   inflating: dev/929.jpg
#   inflating: dev/93.jpg
#   inflating: dev/930.jpg
#   inflating: dev/931.jpg
#   inflating: dev/932.jpg
#   inflating: dev/933.jpg
#   inflating: dev/934.jpg
#   inflating: dev/935.jpg
#   inflating: dev/936.jpg
#   inflating: dev/937.jpg
#   inflating: dev/938.jpg
#   inflating: dev/939.jpg
#   inflating: dev/94.jpg
#   inflating: dev/940.jpg
#   inflating: dev/941.jpg
#   inflating: dev/942.jpg
#   inflating: dev/943.jpg
#   inflating: dev/944.jpg
#   inflating: dev/945.jpg
#   inflating: dev/946.jpg
#   inflating: dev/947.jpg
#   inflating: dev/948.jpg
#   inflating: dev/949.jpg
#   inflating: dev/95.jpg
#   inflating: dev/950.jpg
#   inflating: dev/951.jpg
#   inflating: dev/952.jpg
#   inflating: dev/953.jpg
#   inflating: dev/954.jpg
#   inflating: dev/955.jpg
#   inflating: dev/956.jpg
#   inflating: dev/957.jpg
#   inflating: dev/958.jpg
#   inflating: dev/959.jpg
#   inflating: dev/96.jpg
#   inflating: dev/960.jpg
#   inflating: dev/961.jpg
#   inflating: dev/962.jpg
#   inflating: dev/963.jpg
#   inflating: dev/964.jpg
#   inflating: dev/965.jpg
#   inflating: dev/966.jpg
#   inflating: dev/967.jpg
#   inflating: dev/968.jpg
#   inflating: dev/969.jpg
#   inflating: dev/97.jpg
#   inflating: dev/970.jpg
#   inflating: dev/971.jpg
#   inflating: dev/972.jpg
#   inflating: dev/973.jpg
#   inflating: dev/974.jpg
#   inflating: dev/975.jpg
#   inflating: dev/976.jpg
#   inflating: dev/977.jpg
#   inflating: dev/978.jpg
#   inflating: dev/979.jpg
#   inflating: dev/98.jpg
#   inflating: dev/980.jpg
#   inflating: dev/981.jpg
#   inflating: dev/982.jpg
#   inflating: dev/983.jpg
#   inflating: dev/984.jpg
#   inflating: dev/985.jpg
#   inflating: dev/986.jpg
#   inflating: dev/987.jpg
#   inflating: dev/988.jpg
#   inflating: dev/989.jpg
#   inflating: dev/99.jpg
#   inflating: dev/990.jpg
#   inflating: dev/991.jpg
#   inflating: dev/992.jpg
#   inflating: dev/993.jpg
#   inflating: dev/994.jpg
#   inflating: dev/995.jpg
#   inflating: dev/996.jpg
#   inflating: dev/997.jpg
#   inflating: dev/998.jpg
#   inflating: dev/999.jpg

# %%
# libraries

import os
import re
import zipfile

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score

from tqdm.notebook import tqdm
from pickle import dump, load

from pathlib import Path
from PIL import Image
import cv2

import tensorflow as tf
from keras.applications import DenseNet121
from tensorflow.keras import layers, activations, models
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import load_img, img_to_array, to_categorical

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
nltk.download("wordnet")
nltk.download('omw-1.4')
from nltk.corpus import wordnet as wn
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# make dataset

img_train = Path('/content/train_ende')
img_train = list(img_train.glob(r'**/*.jpg'))
img_train = pd.Series(img_train).astype(str)
img_train = pd.Series(sorted(img_train, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_train = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_train.txt', names=['sentences'], header=None)
lbl_train = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/sentiment_train.txt',names=['labels'], header=None)
train_set = pd.concat([img_train, txt_train, lbl_train], axis=1)

img_val = Path('/content/dev')
img_val = list(img_val.glob(r'**/*.jpg'))
img_val = pd.Series(img_val).astype(str)
img_val = pd.Series(sorted(img_val, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_val = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_dev.txt', names=['sentences'], header=None)
lbl_val = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/sentiment_dev.txt',names=['labels'], header=None)
val_set = pd.concat([img_val, txt_val, lbl_val], axis=1)

img_test = Path('/content/test')
img_test = list(img_test.glob(r'**/*.jpg'))
img_test = pd.Series(img_test).astype(str)
img_test = pd.Series(sorted(img_test, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_test = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_test.txt', names=['sentences'], header=None)
lbl_test = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/sentiment_test.txt',names=['labels'], header=None)
test_set = pd.concat([img_test, txt_test, lbl_test], axis=1)

# %%
def resize(img):
  img = plt.imread(img)
  resized_image = cv2.resize(img, (128,128), interpolation=cv2.INTER_AREA)
  resized_image = np.expand_dims(resized_image, axis=0)
  return resized_image

# %%
resized_train_images = np.array([resize(img) for img in train_set['images']]).reshape(len(train_set['images']), 128, 128, 3)
resized_val_images = np.array([resize(img) for img in val_set['images']]).reshape(len(val_set['images']), 128, 128, 3)
resized_test_images = np.array([resize(img) for img in test_set['images']]).reshape(len(test_set['images']), 128, 128, 3)

train_labels = train_set.labels.values
val_labels = val_set.labels.values
test_labels = test_set.labels.values

# %%
def clean_text(sentence):
  sentence = str(sentence).lower()
  sentence = re.sub('[^a-z]',' ',sentence)
  sentence = word_tokenize(sentence)
  stop_words = stopwords.words('english')
  sentence = [i for i in sentence if i not in stop_words]
  sentence = [i for i in sentence if len(i)>1]
  sentence = ' '.join(sentence)
  return sentence

# %%
train_set['sentences'] = train_set['sentences'].apply(clean_text)
val_set['sentences'] = val_set['sentences'].apply(clean_text)
test_set['sentences'] = test_set['sentences'].apply(clean_text)

train_sentences = train_set.sentences.values
val_sentences = val_set.sentences.values
test_sentences = test_set.sentences.values

# %%
# !wget --no-check-certificate \
http://nlp.stanford.edu/data/glove.6B.zip \
-O /tmp/glove.6B.zip

with zipfile.ZipFile('/tmp/glove.6B.zip', 'r') as zip_ref:
    zip_ref.extractall('/tmp/glove')

f = open('/tmp/glove/glove.6B.50d.txt')

glove_vecs = {}

for line in f:
    values = line.split()
    word = values[0]
    vec = np.asarray(values[1:], dtype="float32")
    glove_vecs[word] = vec
f.close()
# Out:
# --2023-02-12 07:48:24--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2023-02-12 07:48:25--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2023-02-12 07:48:25--  https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘/tmp/glove.6B.zip’
#
# /tmp/glove.6B.zip   100%[===================>] 822.24M  5.01MB/s    in 2m 39s
#
# 2023-02-12 07:51:04 (5.16 MB/s) - ‘/tmp/glove.6B.zip’ saved [862182613/862182613]

# %%
all_centences = np.append(train_sentences,val_sentences)

tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_centences)
word2idx = tokenizer.word_index

glove_embedding_matrix = np.zeros((len(word2idx) + 1, 50))
for word, i in word2idx.items():
  if i < len(word2idx):
    embedding_vector = glove_vecs.get(word)
    if embedding_vector is not None:
      glove_embedding_matrix[i] = embedding_vector

train_sequences = tokenizer.texts_to_sequences(train_sentences)
train_padded = pad_sequences(train_sequences, maxlen=10)

val_sequences = tokenizer.texts_to_sequences(val_sentences)
val_padded = pad_sequences(val_sequences, maxlen=10)

test_sequences = tokenizer.texts_to_sequences(test_sentences)
test_padded = pad_sequences(test_sequences, maxlen=10)

# %%
# texts representation

txt_input = layers.Input(shape=(None,))
embed_layer = layers.Embedding(input_dim=glove_embedding_matrix.shape[0],
                                    output_dim=glove_embedding_matrix.shape[1],
                                    mask_zero=True,
                                    weights=[glove_embedding_matrix],
                                    trainable=False)(txt_input)
txt_representation = layers.Bidirectional(layers.LSTM(512))(embed_layer)

# %%
# image representation

dense_layer = DenseNet121(weights='imagenet', input_shape=(128,128,3), include_top=False)
dense_layer.trainable = False
img_input = layers.Input(shape=(128,128,3))
x = dense_layer(img_input, training=False)
x = layers.Flatten()(x)
img_representation = layers.Dense(256, activation='relu', kernel_initializer='he_normal')(x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step

# %%
concat = layers.concatenate([img_representation,txt_representation], axis=-1)
output = layers.Dense(3, activation='softmax')(concat)
model = models.Model(inputs=[img_input, txt_input], outputs=output)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  densenet121 (Functional)       (None, 4, 4, 1024)   7037504     ['input_3[0][0]']
#
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  flatten (Flatten)              (None, 16384)        0           ['densenet121[0][0]']
#
#  embedding (Embedding)          (None, None, 50)     526950      ['input_1[0][0]']
#
#  dense (Dense)                  (None, 256)          4194560     ['flatten[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024)         2306048     ['embedding[0][0]']
#
#  concatenate (Concatenate)      (None, 1280)         0           ['dense[0][0]',
#                                                                   'bidirectional[0][0]']
#
#  dense_1 (Dense)                (None, 3)            3843        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 14,068,905
# Trainable params: 6,504,451
# Non-trainable params: 7,564,454
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit([resized_train_images, train_padded], train_labels, epochs=10, batch_size=64, validation_data=([resized_val_images, val_padded], val_labels))
# Out:
# Epoch 1/10
# 317/317 [==============================] - 71s 145ms/step - loss: 2.0790 - accuracy: 0.4249 - val_loss: 1.1909 - val_accuracy: 0.4446
# Epoch 2/10
# 317/317 [==============================] - 39s 122ms/step - loss: 0.9965 - accuracy: 0.5234 - val_loss: 1.0558 - val_accuracy: 0.4675
# Epoch 3/10
# 317/317 [==============================] - 39s 124ms/step - loss: 0.9376 - accuracy: 0.5500 - val_loss: 1.0876 - val_accuracy: 0.4628
# Epoch 4/10
# 317/317 [==============================] - 39s 122ms/step - loss: 0.9135 - accuracy: 0.5737 - val_loss: 1.0683 - val_accuracy: 0.4869
# Epoch 5/10
# 317/317 [==============================] - 38s 120ms/step - loss: 0.8761 - accuracy: 0.5955 - val_loss: 1.0521 - val_accuracy: 0.4835
# Epoch 6/10
# 317/317 [==============================] - 38s 120ms/step - loss: 0.8234 - accuracy: 0.6281 - val_loss: 1.0766 - val_accuracy: 0.4762
# Epoch 7/10
# 317/317 [==============================] - 39s 122ms/step - loss: 0.7638 - accuracy: 0.6570 - val_loss: 1.1254 - val_accuracy: 0.4709
# Epoch 8/10
# 317/317 [==============================] - 39s 122ms/step - loss: 0.6689 - accuracy: 0.7107 - val_loss: 1.2127 - val_accuracy: 0.4778
# Epoch 9/10
# 317/317 [==============================] - 39s 122ms/step - loss: 0.5770 - accuracy: 0.7522 - val_loss: 1.3499 - val_accuracy: 0.4663
# Epoch 10/10
# 317/317 [==============================] - 39s 122ms/step - loss: 0.4889 - accuracy: 0.7933 - val_loss: 1.4808 - val_accuracy: 0.4709

# %%
y_pred = model.predict([resized_test_images, test_padded])
y_pred = np.argmax(y_pred, axis=1)
print('Accuracy: ', accuracy_score(test_labels, y_pred))
# Out:
# 159/159 [==============================] - 12s 42ms/step
# Accuracy:  0.4487862640615749

# %%
# free up RAM
# %reset -f

# %% [markdown]
# ## Subpart 2: Pre-trained Transformer Backbones

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 66.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 102.5 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.12.0 tokenizers-0.13.2 transformers-4.26.1

# %%
# libraries

import os
import re
import zipfile

import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score

from tqdm.notebook import tqdm

from pathlib import Path
from PIL import Image

from transformers import AutoProcessor
from tensorflow.keras import layers, activations, models
from tensorflow.keras.preprocessing.sequence import pad_sequences

# pre-trained transformer for image-text representation
processor = AutoProcessor.from_pretrained("openai/clip-vit-base-patch32")
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]

# %%
# make dataset

img_train = Path('/content/train_ende')
img_train = list(img_train.glob(r'**/*.jpg'))
img_train = pd.Series(img_train).astype(str)
img_train = pd.Series(sorted(img_train, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_train = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_train.txt', names=['sentences'], header=None)
train_set = pd.concat([img_train, txt_train], axis=1)

img_val = Path('/content/dev')
img_val = list(img_val.glob(r'**/*.jpg'))
img_val = pd.Series(img_val).astype(str)
img_val = pd.Series(sorted(img_val, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_val = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_dev.txt', names=['sentences'], header=None)
val_set = pd.concat([img_val, txt_val], axis=1)

img_test = Path('/content/test')
img_test = list(img_test.glob(r'**/*.jpg'))
img_test = pd.Series(img_test).astype(str)
img_test = pd.Series(sorted(img_test, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_test = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_test.txt', names=['sentences'], header=None)
test_set = pd.concat([img_test, txt_test], axis=1)

# %%
def text_representation(dataset):
  text_representation=[]
  for i in tqdm(range(len(dataset))):
    text_representation.append(processor(text=dataset['sentences'][i], images=Image.open(dataset['images'][i]), padding=True)['input_ids'])
  text_representation = pad_sequences(text_representation, maxlen=15)
  return text_representation

train_text_representation = text_representation(train_set[:5000])
np.save('train_text_representation.npy', train_text_representation)
val_text_representation = text_representation(val_set[:1000])
np.save('val_text_representation.npy', val_text_representation)
test_text_representation = text_representation(test_set[:1000])
np.save('test_text_representation.npy', test_text_representation)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
# %reset -f

# libraries

import os
import re
import zipfile

import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score

from tqdm.notebook import tqdm

from pathlib import Path
from PIL import Image

from transformers import AutoProcessor
from tensorflow.keras import layers, activations, models

processor = AutoProcessor.from_pretrained("openai/clip-vit-base-patch32")

# make dataset

img_train = Path('/content/train_ende')
img_train = list(img_train.glob(r'**/*.jpg'))
img_train = pd.Series(img_train).astype(str)
img_train = pd.Series(sorted(img_train, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_train = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_train.txt', names=['sentences'], header=None)
train_set = pd.concat([img_train, txt_train], axis=1)

img_val = Path('/content/dev')
img_val = list(img_val.glob(r'**/*.jpg'))
img_val = pd.Series(img_val).astype(str)
img_val = pd.Series(sorted(img_val, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_val = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_dev.txt', names=['sentences'], header=None)
val_set = pd.concat([img_val, txt_val], axis=1)

img_test = Path('/content/test')
img_test = list(img_test.glob(r'**/*.jpg'))
img_test = pd.Series(img_test).astype(str)
img_test = pd.Series(sorted(img_test, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_test = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_test.txt', names=['sentences'], header=None)
test_set = pd.concat([img_test, txt_test], axis=1)

# %%
def image_representation(dataset):
  image_representation=[]
  for i in tqdm(range(len(dataset))):
    image_representation.append(np.expand_dims(processor(text=dataset['sentences'][i],
                                                         images=Image.open(dataset['images'][i]),
                                                         padding=True)['pixel_values'], axis=0))
  return image_representation

train_image_representation = image_representation(train_set[:5000])
np.save('train_image_representation.npy', train_image_representation)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]

# %%
# %reset -f

# libraries

import os
import re
import zipfile

import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score
from tqdm.notebook import tqdm
from pathlib import Path
from PIL import Image

from transformers import AutoProcessor
from tensorflow.keras import layers, activations, models

processor = AutoProcessor.from_pretrained("openai/clip-vit-base-patch32")

# make dataset

img_train = Path('/content/train_ende')
img_train = list(img_train.glob(r'**/*.jpg'))
img_train = pd.Series(img_train).astype(str)
img_train = pd.Series(sorted(img_train, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_train = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_train.txt', names=['sentences'], header=None)
train_set = pd.concat([img_train, txt_train], axis=1)

img_val = Path('/content/dev')
img_val = list(img_val.glob(r'**/*.jpg'))
img_val = pd.Series(img_val).astype(str)
img_val = pd.Series(sorted(img_val, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_val = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_dev.txt', names=['sentences'], header=None)
val_set = pd.concat([img_val, txt_val], axis=1)

img_test = Path('/content/test')
img_test = list(img_test.glob(r'**/*.jpg'))
img_test = pd.Series(img_test).astype(str)
img_test = pd.Series(sorted(img_test, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_test = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_test.txt', names=['sentences'], header=None)
test_set = pd.concat([img_test, txt_test], axis=1)

# %%
def image_representation(dataset):
  image_representation=[]
  for i in tqdm(range(len(dataset))):
    image_representation.append(np.expand_dims(processor(text=dataset['sentences'][i],
                                                         images=Image.open(dataset['images'][i]),
                                                         padding=True)['pixel_values'], axis=0))
  return image_representation

val_image_representation = image_representation(val_set[:1000])
np.save('val_image_representation.npy', val_image_representation)
test_image_representation = image_representation(test_set[:1000])
np.save('test_image_representation.npy', test_image_representation)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
# %reset -f

# libraries

import os
import re
import zipfile

import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score

from PIL import Image
from pathlib import Path
from tqdm.notebook import tqdm

from transformers import AutoProcessor
from tensorflow.keras import layers, activations, models

# make dataset

img_train = Path('/content/train_ende')
img_train = list(img_train.glob(r'**/*.jpg'))
img_train = pd.Series(img_train).astype(str)
img_train = pd.Series(sorted(img_train, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_train = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_train.txt', names=['sentences'], header=None)
lbl_train = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/sentiment_train.txt',names=['labels'], header=None)
train_set = pd.concat([img_train, txt_train, lbl_train], axis=1)

img_val = Path('/content/dev')
img_val = list(img_val.glob(r'**/*.jpg'))
img_val = pd.Series(img_val).astype(str)
img_val = pd.Series(sorted(img_val, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_val = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_dev.txt', names=['sentences'], header=None)
lbl_val = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/sentiment_dev.txt',names=['labels'], header=None)
val_set = pd.concat([img_val, txt_val, lbl_val], axis=1)

img_test = Path('/content/test')
img_test = list(img_test.glob(r'**/*.jpg'))
img_test = pd.Series(img_test).astype(str)
img_test = pd.Series(sorted(img_test, key=lambda x:int(re.findall('(\d+)', x)[0])), name='images')
txt_test = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/english_test.txt', names=['sentences'], header=None)
lbl_test = pd.read_fwf('https://github.com/XL2248/MSCTD/raw/main/MSCTD_data/ende/sentiment_test.txt',names=['labels'], header=None)
test_set = pd.concat([img_test, txt_test, lbl_test], axis=1)

# %%
train_text_representation = np.load('/content/train_text_representation.npy', allow_pickle=True)
val_text_representation = np.load('/content/val_text_representation.npy', allow_pickle=True)
test_text_representation = np.load('/content/test_text_representation.npy', allow_pickle=True)

train_image_representation = np.load('/content/train_image_representation.npy', allow_pickle=True)
train_image_representation = np.array(train_image_representation, dtype='float16').reshape(len(train_image_representation), 224, 224, 3)
val_image_representation = np.load('/content/val_image_representation.npy', allow_pickle=True)
val_image_representation = np.array(val_image_representation, dtype='float16').reshape(len(val_image_representation), 224, 224, 3)
test_image_representation = np.load('/content/test_image_representation.npy', allow_pickle=True)
test_image_representation = np.array(test_image_representation, dtype='float16').reshape(len(test_image_representation), 224, 224, 3)

train_labels = train_set['labels'][:5000].values
val_labels = val_set['labels'][:1000].values
test_labels = test_set['labels'][:1000].values

# %%
text_input = layers.Input(shape=(15,))
text_layer = layers.Dense(64, activation="relu", kernel_initializer='he_normal')(text_input)

image_input = layers.Input(shape=(224,224,3))
image_layer = layers.Flatten()(image_input)

concat = layers.concatenate([image_layer,text_layer])

fc = layers.Dense(256, activation="relu", kernel_initializer='he_normal')(concat)
total_output = layers.Dense(3, activation="softmax")(fc)

model = models.Model(inputs=[text_input,image_input], outputs=total_output)

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit([train_text_representation, train_image_representation], train_labels, epochs=15, batch_size=128,
          validation_data=([val_text_representation, val_image_representation], val_labels))
# Out:
# Epoch 1/15
# 40/40 [==============================] - 8s 114ms/step - loss: 615.3157 - accuracy: 0.3684 - val_loss: 75.4422 - val_accuracy: 0.5920
# Epoch 2/15
# 40/40 [==============================] - 3s 68ms/step - loss: 88.9477 - accuracy: 0.3564 - val_loss: 51.1111 - val_accuracy: 0.4710
# Epoch 3/15
# 40/40 [==============================] - 3s 67ms/step - loss: 52.2291 - accuracy: 0.3714 - val_loss: 42.0369 - val_accuracy: 0.4260
# Epoch 4/15
# 40/40 [==============================] - 4s 100ms/step - loss: 31.7892 - accuracy: 0.3932 - val_loss: 24.2568 - val_accuracy: 0.3830
# Epoch 5/15
# 40/40 [==============================] - 3s 69ms/step - loss: 30.0972 - accuracy: 0.3820 - val_loss: 22.2011 - val_accuracy: 0.4210
# Epoch 6/15
# 40/40 [==============================] - 3s 66ms/step - loss: 31.1268 - accuracy: 0.3808 - val_loss: 84.1881 - val_accuracy: 0.2310
# Epoch 7/15
# 40/40 [==============================] - 3s 72ms/step - loss: 30.1506 - accuracy: 0.3892 - val_loss: 23.5085 - val_accuracy: 0.2670
# Epoch 8/15
# 40/40 [==============================] - 3s 70ms/step - loss: 22.6998 - accuracy: 0.3912 - val_loss: 17.1139 - val_accuracy: 0.5660
# Epoch 9/15
# 40/40 [==============================] - 4s 92ms/step - loss: 23.2672 - accuracy: 0.4020 - val_loss: 23.8008 - val_accuracy: 0.5980
# Epoch 10/15
# 40/40 [==============================] - 3s 74ms/step - loss: 23.1646 - accuracy: 0.3938 - val_loss: 24.6689 - val_accuracy: 0.5300
# Epoch 11/15
# 40/40 [==============================] - 3s 66ms/step - loss: 27.6064 - accuracy: 0.3908 - val_loss: 24.0123 - val_accuracy: 0.4340
# Epoch 12/15
# 40/40 [==============================] - 3s 66ms/step - loss: 21.9725 - accuracy: 0.4012 - val_loss: 12.7122 - val_accuracy: 0.2850
# Epoch 13/15
# 40/40 [==============================] - 3s 84ms/step - loss: 16.1267 - accuracy: 0.4072 - val_loss: 19.3188 - val_accuracy: 0.2790
# Epoch 14/15
# 40/40 [==============================] - 4s 90ms/step - loss: 11.4558 - accuracy: 0.4110 - val_loss: 17.4029 - val_accuracy: 0.2840
# Epoch 15/15
# 40/40 [==============================] - 3s 67ms/step - loss: 10.0831 - accuracy: 0.4300 - val_loss: 12.6231 - val_accuracy: 0.3500

# %%
y_pred = model.predict([test_text_representation, test_image_representation])
y_pred = np.argmax(y_pred, axis=1)
print('Accuracy: ', accuracy_score(test_labels, y_pred))
# Out:
# 32/32 [==============================] - 0s 11ms/step
# Accuracy:  0.368
